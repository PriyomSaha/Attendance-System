# %%
import os
import cv2
import sys
import os
import matplotlib.pyplot as plt
from IPython.display import Image

# %%
# %matplotlib inline

# %%
os.chdir('E:\\dir_001\\')
l = os.listdir()
der = 'E:\\dir_001\\'

# %%
# imagePath = "E:\\dir_001\\"
cascPath = "D:\\python\\Attendance_system_4th_year\\image\\haarcascade_frontalface_default.xml"
faceCascade = cv2.CascadeClassifier(cascPath)

# %%
for i in l:
    #try:
    d = der + i
    c=1
    if not os.path.exists(d+"\\test"):
        os.mkdir(d+"\\test")
    for j in os.listdir(d):
        print(d+j)
        image = cv2.imread(d+'\\'+j)
        print(len(image))
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        # The face or faces in an image are detected
        # This section requires the most adjustments to get accuracy on face being detected.


        faces = faceCascade.detectMultiScale(
            gray,
            scaleFactor=2,  #1.1
            minNeighbors=5, #5
            minSize=(1,1),  #(1,1)
            flags = cv2.CASCADE_SCALE_IMAGE
        )

        #     print("Detected {0} faces!".format(len(faces)))

        # This draws a green rectangle around the faces detected


        for (x, y, w, h) in faces:
            #cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)
            im = image[y:y+h, x:x+w]
            plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
            plt.show()
            cv2.imwrite("{}\\{}\\{}.jpg".format(d,"test",c), im)
            c+=1
        #cv2.resize(image, (960, 540))
#     except Exception as e:
#         print(e)
#         pass
# Out:
# E:\dir_001\Aaron Judge1.jpg
# 320
# E:\dir_001\Aaron Judge10.jpg
# 3517
# E:\dir_001\Aaron Judge100.jpg
# 750
# E:\dir_001\Aaron Judge101.jpg
# 330
# E:\dir_001\Aaron Judge102.jpg
# 435
# E:\dir_001\Aaron Judge103.jpg
# 533
# E:\dir_001\Aaron Judge104.jpg
# 330
# E:\dir_001\Aaron Judge105.jpg
# 720
# E:\dir_001\Aaron Judge106.jpg
# 2776
# E:\dir_001\Aaron Judge107.jpg
# 724
# E:\dir_001\Aaron Judge108.jpg
# 2376
# E:\dir_001\Aaron Judge109.jpg
# 720
# E:\dir_001\Aaron Judge11.jpg
# 359
# E:\dir_001\Aaron Judge110.jpg
# 1200
# E:\dir_001\Aaron Judge111.jpg
# 558
# E:\dir_001\Aaron Judge112.jpg
# 270
# E:\dir_001\Aaron Judge113.jpg
# 883
# E:\dir_001\Aaron Judge114.jpg
# 512
# E:\dir_001\Aaron Judge115.jpg
# 720
# E:\dir_001\Aaron Judge116.jpg
# 807
# E:\dir_001\Aaron Judge117.jpg
# 722
# E:\dir_001\Aaron Judge118.jpg
# 250
# E:\dir_001\Aaron Judge119.jpg
# 400
# E:\dir_001\Aaron Judge12.jpg
# 1398
# E:\dir_001\Aaron Judge120.jpg
# 636
# E:\dir_001\Aaron Judge121.jpg
# 400
# E:\dir_001\Aaron Judge122.jpg
# 800
# E:\dir_001\Aaron Judge123.jpg
# 1333
# E:\dir_001\Aaron Judge124.jpg
# 3456
# E:\dir_001\Aaron Judge125.jpg
# 887
# E:\dir_001\Aaron Judge126.jpg
# 900
# E:\dir_001\Aaron Judge127.jpg
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-c42a0997ab0e> in <module>
#       8         print(d+j)
#       9         image = cv2.imread(d+'\\'+j)
# ---> 10         print(len(image))
#      11         gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#      12
#
# TypeError: object of type 'NoneType' has no len()
